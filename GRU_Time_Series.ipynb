# %% [markdown]
# <a href="https://colab.research.google.com/github/SowjanyaKiran/Time_series_sowanya/blob/main/GRU_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout

# %%
#Read the dataset
# ✅ Step 2: Load Dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
df = pd.read_csv(url, parse_dates=['Month'], index_col='Month')

# %%
df
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
#Summarize the data
df.describe()
# Out:
#        Passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
df.shape
# Out:
# (144, 1)

# %%
df.dtypes
# Out:
# Passengers    int64
# dtype: object

# %%
#Performing EDA
df.isnull().sum()
# Out:
# Passengers    0
# dtype: int64

# %%
#plot
plt.figure(figsize = (10,5))
plt.plot(df , label = 'Monthly passenger')
plt.title("Monthly international airline passengers")
plt.xlabel("Month")
plt.ylabel("Number of passengers")
plt.legend()
plt.grid()
plt.show()

# %%
#Scale dataset
df
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
data = df.values
sc = MinMaxScaler(feature_range = (0 , 1))
scaled_data = sc.fit_transform(data)

# %%
#prepare train and test split
#last 24 months for generating 12 input -> 12 output sequences
test_data = scaled_data[-24:]
x_test , y_test = [] , []

for i in range(12 , 24):
  x_test.append(test_data[i-12:i , 0])
  y_test.append(test_data[i , 0])

x_test , y_test = np.array(x_test) , np.array(y_test)
x_test = x_test.reshape((x_test.shape[0] , x_test.shape[1] , 1))

# %%
x_test[0] , y_test[0]
# Out:
# (array([[0.49420849],
#         [0.45945946],
#         [0.58301158],
#         [0.56370656],
#         [0.61003861],
#         [0.71042471],
#         [0.85714286],
#         [0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108]]),
#  np.float64(0.6042471042471043))

# %%
#Train data = all before last 12 months
train_data = scaled_data[:-12]
x_train , y_train = [] , []

for i in range(12 , len(train_data)):
  x_train.append(train_data[i-12:i , 0])
  y_train.append(train_data[i , 0])

x_train , y_train = np.array(x_train) , np.array(y_train)
x_train = x_train.reshape((x_train.shape[0] , x_train.shape[1] , 1))

# %%
x_train[0] , y_train[0]
# Out:
# (array([[0.01544402],
#         [0.02702703],
#         [0.05405405],
#         [0.04826255],
#         [0.03281853],
#         [0.05984556],
#         [0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703]]),
#  np.float64(0.02123552123552122))

# %%
#Build and Train the RNN Model
model = Sequential()
model.add(GRU(units=50, return_sequences=True, input_shape=(12, 1)))
model.add(Dropout(0.2))
model.add(GRU(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 12, 50)         │         7,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,301 (91.02 KB)
#  Trainable params: 23,301 (91.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train, y_train, epochs=350)
# Out:
# Epoch 1/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.1648
# Epoch 2/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0542
# Epoch 3/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0204
# Epoch 4/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0268
# Epoch 5/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0275
# Epoch 6/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0165
# Epoch 7/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0164
# Epoch 8/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0173
# Epoch 9/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0154
# Epoch 10/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0146
# Epoch 11/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0115
# Epoch 12/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0129
# Epoch 13/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0123
# Epoch 14/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0132
# Epoch 15/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0127
# Epoch 16/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0104
# Epoch 17/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0098
# Epoch 18/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0103
# Epoch 19/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0124
# Epoch 20/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0108
# Epoch 21/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0126
# Epoch 22/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0105
# Epoch 23/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0104
# Epoch 24/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0105
# Epoch 25/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0090
# Epoch 26/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0097
# Epoch 27/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0107
# Epoch 28/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0100
# Epoch 29/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0085
# Epoch 30/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0099
# Epoch 31/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0095
# Epoch 32/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0090
# Epoch 33/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0109
# Epoch 34/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0090
# Epoch 35/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0090
# Epoch 36/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0085
# Epoch 37/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0106
# Epoch 38/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0083
# Epoch 39/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0087
# Epoch 40/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0089
# Epoch 41/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0086
# Epoch 42/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0077
# Epoch 43/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0064
# Epoch 44/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0082
# Epoch 45/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0074
# Epoch 46/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0084
# Epoch 47/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0087
# Epoch 48/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0084
# Epoch 49/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0075
# Epoch 50/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0076
# Epoch 51/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0081
# Epoch 52/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0073
# Epoch 53/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0074
# Epoch 54/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0096
# Epoch 55/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0086
# Epoch 56/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0078
# Epoch 57/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0060
# Epoch 58/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0067
# Epoch 59/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0055
# Epoch 60/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0064
# Epoch 61/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0061
# Epoch 62/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0057
# Epoch 63/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0075
# Epoch 64/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0063
# Epoch 65/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0057
# Epoch 66/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0058
# Epoch 67/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0048
# Epoch 68/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0074
# Epoch 69/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0063
# Epoch 70/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0074
# Epoch 71/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0057
# Epoch 72/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0063
# Epoch 73/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0064
# Epoch 74/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0054
# Epoch 75/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0051
# Epoch 76/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0057
# Epoch 77/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0058
# Epoch 78/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0045
# Epoch 79/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0064
# Epoch 80/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0046
# Epoch 81/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0049
# Epoch 82/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0053
# Epoch 83/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0040
# Epoch 84/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0038
# Epoch 85/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0050
# Epoch 86/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0053
# Epoch 87/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0033
# Epoch 88/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038
# Epoch 89/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0054
# Epoch 90/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0053
# Epoch 91/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0045
# Epoch 92/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0046
# Epoch 93/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0046
# Epoch 94/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0036
# Epoch 95/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0049
# Epoch 96/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0046
# Epoch 97/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0038
# Epoch 98/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0045
# Epoch 99/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0045
# Epoch 100/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0038
# Epoch 101/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038
# Epoch 102/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0043
# Epoch 103/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0044
# Epoch 104/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0052
# Epoch 105/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031
# Epoch 106/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0047
# Epoch 107/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0046
# Epoch 108/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0049
# Epoch 109/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042
# Epoch 110/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0032
# Epoch 111/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040
# Epoch 112/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0032
# Epoch 113/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042
# Epoch 114/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0047
# Epoch 115/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0029
# Epoch 116/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0023
# Epoch 117/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0034
# Epoch 118/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0035
# Epoch 119/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0042
# Epoch 120/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036
# Epoch 121/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038
# Epoch 122/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036
# Epoch 123/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0035
# Epoch 124/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0042
# Epoch 125/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036
# Epoch 126/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0040
# Epoch 127/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037
# Epoch 128/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0041
# Epoch 129/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036
# Epoch 130/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0041
# Epoch 131/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0031
# Epoch 132/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0034
# Epoch 133/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039
# Epoch 134/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0045
# Epoch 135/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 136/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028
# Epoch 137/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029
# Epoch 138/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0034
# Epoch 139/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0030
# Epoch 140/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0046
# Epoch 141/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037
# Epoch 142/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0036
# Epoch 143/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0027
# Epoch 144/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0037
# Epoch 145/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0025
# Epoch 146/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0026
# Epoch 147/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0038
# Epoch 148/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0038
# Epoch 149/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0044
# Epoch 150/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 151/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0038
# Epoch 152/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0027
# Epoch 153/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0024
# Epoch 154/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0028
# Epoch 155/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028
# Epoch 156/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0027
# Epoch 157/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0047
# Epoch 158/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0042
# Epoch 159/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0047
# Epoch 160/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0037
# Epoch 161/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0038
# Epoch 162/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0037
# Epoch 163/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036
# Epoch 164/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0033
# Epoch 165/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0026
# Epoch 166/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0033
# Epoch 167/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0034
# Epoch 168/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0025
# Epoch 169/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0033
# Epoch 170/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0030
# Epoch 171/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0028
# Epoch 172/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0025
# Epoch 173/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0033
# Epoch 174/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0049
# Epoch 175/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0027
# Epoch 176/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0036
# Epoch 177/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0032
# Epoch 178/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0025
# Epoch 179/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0030
# Epoch 180/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0032
# Epoch 181/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036
# Epoch 182/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0034
# Epoch 183/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0035
# Epoch 184/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0037
# Epoch 185/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0044
# Epoch 186/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 187/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0037
# Epoch 188/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0040
# Epoch 189/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0032
# Epoch 190/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0041
# Epoch 191/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0030
# Epoch 192/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0030
# Epoch 193/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0034
# Epoch 194/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029
# Epoch 195/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029
# Epoch 196/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0027
# Epoch 197/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029
# Epoch 198/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0030
# Epoch 199/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0033
# Epoch 200/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031
# Epoch 201/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0034
# Epoch 202/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0027
# Epoch 203/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0026
# Epoch 204/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028
# Epoch 205/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028
# Epoch 206/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0037
# Epoch 207/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0035
# Epoch 208/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0040
# Epoch 209/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0035
# Epoch 210/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0038
# Epoch 211/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0025
# Epoch 212/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0025
# Epoch 213/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0045
# Epoch 214/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0033
# Epoch 215/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0039
# Epoch 216/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029
# Epoch 217/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0038
# Epoch 218/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0031
# Epoch 219/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0036
# Epoch 220/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028
# Epoch 221/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0027
# Epoch 222/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0030
# Epoch 223/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0034
# Epoch 224/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029
# Epoch 225/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029
# Epoch 226/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0035
# Epoch 227/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0022
# Epoch 228/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0029
# Epoch 229/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0024
# Epoch 230/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0027
# Epoch 231/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0036
# Epoch 232/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0028
# Epoch 233/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0028
# Epoch 234/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0025
# Epoch 235/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0034
# Epoch 236/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029
# Epoch 237/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0038
# Epoch 238/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0033
# Epoch 239/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0021
# Epoch 240/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022
# Epoch 241/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025
# Epoch 242/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022
# Epoch 243/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0031
# Epoch 244/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0039
# Epoch 245/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0026
# Epoch 246/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0023
# Epoch 247/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029
# Epoch 248/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0021
# Epoch 249/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0030
# Epoch 250/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0021
# Epoch 251/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0030
# Epoch 252/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0028
# Epoch 253/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0027
# Epoch 254/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0029
# Epoch 255/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0036
# Epoch 256/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0027
# Epoch 257/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0030
# Epoch 258/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0023
# Epoch 259/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0029
# Epoch 260/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0028
# Epoch 261/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0034
# Epoch 262/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0029
# Epoch 263/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0025
# Epoch 264/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0026
# Epoch 265/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0025
# Epoch 266/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0027
# Epoch 267/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0023
# Epoch 268/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 269/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028
# Epoch 270/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0025
# Epoch 271/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0026
# Epoch 272/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031
# Epoch 273/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028
# Epoch 274/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029
# Epoch 275/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0041
# Epoch 276/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0024
# Epoch 277/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028
# Epoch 278/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0029
# Epoch 279/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0027
# Epoch 280/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0032
# Epoch 281/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021
# Epoch 282/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028
# Epoch 283/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0025
# Epoch 284/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0019
# Epoch 285/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0024
# Epoch 286/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0033
# Epoch 287/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0019
# Epoch 288/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0027
# Epoch 289/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0026
# Epoch 290/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0030
# Epoch 291/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0022
# Epoch 292/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0030
# Epoch 293/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0025
# Epoch 294/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0021
# Epoch 295/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0020
# Epoch 296/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0025
# Epoch 297/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0023
# Epoch 298/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0030
# Epoch 299/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0026
# Epoch 300/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0023
# Epoch 301/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0021
# Epoch 302/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0026
# Epoch 303/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0018
# Epoch 304/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0026
# Epoch 305/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0030
# Epoch 306/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025
# Epoch 307/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021
# Epoch 308/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0032
# Epoch 309/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0027
# Epoch 310/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029
# Epoch 311/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0024
# Epoch 312/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0026
# Epoch 313/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0023
# Epoch 314/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0024
# Epoch 315/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 316/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0027
# Epoch 317/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0024
# Epoch 318/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028
# Epoch 319/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0028
# Epoch 320/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0020
# Epoch 321/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0022
# Epoch 322/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0023
# Epoch 323/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0019
# Epoch 324/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0023
# Epoch 325/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0024
# Epoch 326/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0029
# Epoch 327/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0018
# Epoch 328/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0029
# Epoch 329/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0021
# Epoch 330/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0021
# Epoch 331/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0022
# Epoch 332/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0023
# Epoch 333/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0021
# Epoch 334/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0019
# Epoch 335/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0021
# Epoch 336/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0025
# Epoch 337/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0021
# Epoch 338/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0025
# Epoch 339/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0022
# Epoch 340/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0026
# Epoch 341/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018
# Epoch 342/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030
# Epoch 343/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0026
# Epoch 344/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0017
# Epoch 345/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0025
# Epoch 346/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023
# Epoch 347/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0025
# Epoch 348/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0026
# Epoch 349/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025
# Epoch 350/350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0032

# %%
#Predict the Last 12 Months (Test Set)
x_test
# Out:
# array([[[0.49420849],
#         [0.45945946],
#         [0.58301158],
#         [0.56370656],
#         [0.61003861],
#         [0.71042471],
#         [0.85714286],
#         [0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108]],
#
#        [[0.45945946],
#         [0.58301158],
#         [0.56370656],
#         [0.61003861],
#         [0.71042471],
#         [0.85714286],
#         [0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ]],
#
#        [[0.58301158],
#         [0.56370656],
#         [0.61003861],
#         [0.71042471],
#         [0.85714286],
#         [0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405]],
#
#        [[0.56370656],
#         [0.61003861],
#         [0.71042471],
#         [0.85714286],
#         [0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811]],
#
#        [[0.61003861],
#         [0.71042471],
#         [0.85714286],
#         [0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811],
#         [0.68918919]],
#
#        [[0.71042471],
#         [0.85714286],
#         [0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811],
#         [0.68918919],
#         [0.71042471]],
#
#        [[0.85714286],
#         [0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811],
#         [0.68918919],
#         [0.71042471],
#         [0.83204633]],
#
#        [[0.87837838],
#         [0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811],
#         [0.68918919],
#         [0.71042471],
#         [0.83204633],
#         [1.        ]],
#
#        [[0.69305019],
#         [0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811],
#         [0.68918919],
#         [0.71042471],
#         [0.83204633],
#         [1.        ],
#         [0.96911197]],
#
#        [[0.58494208],
#         [0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811],
#         [0.68918919],
#         [0.71042471],
#         [0.83204633],
#         [1.        ],
#         [0.96911197],
#         [0.77992278]],
#
#        [[0.4980695 ],
#         [0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811],
#         [0.68918919],
#         [0.71042471],
#         [0.83204633],
#         [1.        ],
#         [0.96911197],
#         [0.77992278],
#         [0.68918919]],
#
#        [[0.58108108],
#         [0.6042471 ],
#         [0.55405405],
#         [0.60810811],
#         [0.68918919],
#         [0.71042471],
#         [0.83204633],
#         [1.        ],
#         [0.96911197],
#         [0.77992278],
#         [0.68918919],
#         [0.55212355]]])

# %%
predicted_test_scaled = model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step

# %%
predicted_test_scaled
# Out:
# array([[0.52980834],
#        [0.5476539 ],
#        [0.5523955 ],
#        [0.6241619 ],
#        [0.70906174],
#        [0.74653965],
#        [0.8647168 ],
#        [0.9345768 ],
#        [0.7545988 ],
#        [0.5913112 ],
#        [0.56957895],
#        [0.4949231 ]], dtype=float32)

# %%
predicted_test = sc.inverse_transform(predicted_test_scaled)

# %%
predicted_test_scaled
# Out:
# array([[0.52980834],
#        [0.5476539 ],
#        [0.5523955 ],
#        [0.6241619 ],
#        [0.70906174],
#        [0.74653965],
#        [0.8647168 ],
#        [0.9345768 ],
#        [0.7545988 ],
#        [0.5913112 ],
#        [0.56957895],
#        [0.4949231 ]], dtype=float32)

# %%
y_test
# Out:
# array([0.6042471 , 0.55405405, 0.60810811, 0.68918919, 0.71042471,
#        0.83204633, 1.        , 0.96911197, 0.77992278, 0.68918919,
#        0.55212355, 0.63320463])

# %%
# Inverse scale real test values
real_test = sc.inverse_transform(y_test.reshape(-1, 1))

# %%
real_test
# Out:
# array([[417.],
#        [391.],
#        [419.],
#        [461.],
#        [472.],
#        [535.],
#        [622.],
#        [606.],
#        [508.],
#        [461.],
#        [390.],
#        [432.]])

# %%
test_dates = df.index[-12:]

plt.figure(figsize=(10, 5))
plt.plot(test_dates, real_test, marker='o', label='Actual Passengers')
plt.plot(test_dates, predicted_test, marker='s', linestyle='--', label='Predicted Passengers')
plt.title("✈️ Actual vs Predicted Airline Passengers (Last 12 Months)")
plt.xlabel("Month")
plt.ylabel("Passenger Count")
plt.grid(True)
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
import math

# ✅ Calculate RMSE
rmse = math.sqrt(mean_squared_error(real_test, predicted_test))
print("RMSE on Test Set (Last 12 Months):", rmse)
# Out:
# RMSE on Test Set (Last 12 Months): 39.38441901903078

# %%
#Predict the Next 12 Months (Future Forecast)
# Use the last 12 months of the entire dataset as input
last_sequence = scaled_data[-12:].reshape(1, 12, 1)

future_predictions_scaled = []

for _ in range(12):  # Predict next 12 months
    next_pred_scaled = model.predict(last_sequence)[0, 0]
    future_predictions_scaled.append(next_pred_scaled)

    # Update input sequence
    new_input = np.append(last_sequence[0, 1:, 0], next_pred_scaled)
    last_sequence = new_input.reshape(1, 12, 1)

# Inverse scale the future predictions
future_predictions = sc.inverse_transform(np.array(future_predictions_scaled).reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
future_predictions
# Out:
# array([[404.88873],
#        [380.0141 ],
#        [389.88278],
#        [420.7716 ],
#        [458.56088],
#        [505.26724],
#        [552.3578 ],
#        [565.67944],
#        [523.2012 ],
#        [460.58582],
#        [407.0625 ],
#        [383.89728]], dtype=float32)

# %%
#Plot Original + Future 12 Month Predictions
# Create future date index (after last date in dataset)
future_dates = pd.date_range(start=df.index[-1] + pd.DateOffset(months=1), periods=12, freq='MS')

# Plot full data + future
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Passengers'], label='Actual Data')
plt.plot(future_dates, future_predictions, label='Future Forecast (Next 12 Months)', linestyle='--', marker='o')
plt.title("Airline Passenger Forecast | Future 12 Months")
plt.xlabel("Time")
plt.ylabel("Passenger Count")
plt.grid(True)
plt.legend()
plt.show()
